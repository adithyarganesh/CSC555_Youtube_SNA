# %%
import networkx as nx
G = nx.read_gpickle('overall_graph.gpickle')

# %%
katz = nx.algorithms.centrality.katz_centrality(G, alpha=0.25, max_iter = 50)

# %%
print(katz)

# %%
import networkx as nx

# %%
z = nx.pagerank(G, alpha = 0.85, max_iter = 6)

# %%
z
# Out:
# {1048576: 1.4728766936224156e-07,
#  1: 8.649874467887612e-06,
#  2: 2.6795643660921454e-05,
#  3: 2.7397737544319664e-06,
#  4: 0.0005433314069431776,
#  5: 4.0477196136286614e-05,
#  1048579: 1.6877150303524403e-07,
#  1048584: 1.37027890241668e-07,
#  11: 1.0032363995778126e-05,
#  13: 6.913045862566111e-06,
#  14: 1.5902443228955197e-05,
#  15: 9.657391630454233e-06,
#  16: 1.7701299162040582e-06,
#  17: 9.069691219669484e-07,
#  18: 8.206136460970113e-05,
#  19: 5.901698048050194e-06,
#  20: 2.492290237974271e-06,
#  21: 2.6259064844406305e-07,
#  22: 0.00046957101674353544,
#  23: 8.832462223017542e-07,
#  24: 1.4529508379364167e-06,
#  25: 4.539360952758839e-07,
#  26: 1.3977378637824413e-05,
#  27: 1.0658121109192796e-05,
#  28: 1.3249967010225532e-05,
#  29: 5.450169187890788e-07,
#  30: 1.47465140194677e-07,
#  1048598: 2.329212201405108e-06,
#  32: 7.624481371946947e-06,
#  33: 3.065414351000069e-05,
#  34: 0.00014272297531613823,
#  35: 8.287557189505454e-06,
# ...

# %%
f =  open("youtube_community.txt", "r")

# %%
f
# Out:
# <_io.TextIOWrapper name='youtube_community.txt' mode='r' encoding='UTF-8'>

# %%
lis = []
t = []
for i in f:
    pr = 0
    temp = i.split(",")
    for j in temp:
        pr += z[int(j)]
    lis.append(pr)
    t.append(len(temp))

# %%
plt.plot([x for x in range(len(lis))], lis)

# %%
plt.plot([x for x in range(len(t))], t)

# %%
plt.plot(a, b)

# %%
a, b = zip(*sorted(zip(t, lis)))
plt.plot(a, b)

# %%
from collections import defaultdict 
dd = defaultdict(list)
for i,j in zip(a,b):
    print(i,j)

# %%
dd[0].append(1)

# %%
# Out:
# 2 4.937074055913903e-07
# 2 5.212177684772615e-07
# 2 5.636097797172391e-07
# 2 5.641372364689703e-07
# 2 5.736858502971233e-07
# 2 5.736858502971233e-07
# 2 5.736858502971233e-07
# 2 5.969544040369247e-07
# 2 6.097920372445935e-07
# 2 6.115301185534602e-07
# 2 6.393797846533154e-07
# 2 6.393797846533154e-07
# 2 6.393797846533154e-07
# 2 6.520443752758983e-07
# 2 6.520443752758983e-07
# 2 6.520443752758983e-07
# 2 6.520443752758983e-07
# 2 6.624302811985499e-07
# 2 6.624302811985499e-07
# 2 6.741834813356907e-07
# 2 6.741834813356907e-07
# 2 6.741834813356907e-07
# 2 6.741834813356907e-07
# 2 6.758632098736642e-07
# 2 6.758632098736642e-07
# 2 6.827617444997172e-07
# 2 7.000520767572155e-07
# 2 7.025860307605246e-07
# 2 7.062931053621662e-07
# 2 7.221402271757205e-07
# 2 7.238081076857138e-07
# 2 7.300994869986377e-07
# 2 7.332542432844351e-07
# 2 7.367574479646274e-07
# 2 7.443322546316586e-07
# 2 7.690562495498639e-07
# 2 7.692992168771925e-07
# 2 7.693332694232733e-07
# ...

# %%
plt.plot(t, lis)

# %%
plt.plot([x for x in range(len(b))], b)

# %%
plt.plot(a)

# %%
lis
# Out:
# [2.4470364650751534e-05,
#  4.868907156413287e-06,
#  1.0683852008436104e-06,
#  6.967569590043159e-07,
#  7.343899010893554e-07,
#  2.848803129357126e-06,
#  9.077708985614558e-07,
#  1.6748725814822972e-06,
#  4.3594969549450555e-07,
#  1.2033102412557154e-06,
#  6.835524985580411e-06,
#  2.392914540993537e-06,
#  9.476390890273716e-06,
#  6.528078752349091e-07,
#  4.376450910067283e-06,
#  3.601571066751491e-05,
#  1.0513433889712207e-05,
#  2.1729683931679427e-06,
#  1.4558835236961547e-05,
#  5.78932350473126e-06,
#  2.276844423914184e-06,
#  1.0673546445385515e-06,
#  5.373935908945965e-06,
#  6.961682364478845e-07,
#  7.130568814221963e-06,
#  6.95811987869872e-05,
#  9.24130922795117e-06,
#  5.051032673419467e-06,
#  2.2386517726994097e-06,
#  1.187068235330894e-06,
#  3.3121514059927493e-07,
#  3.3905430724413753e-06,
#  1.5414401294315967e-06,
#  8.880677332263512e-07,
#  2.0443945761873633e-05,
#  1.3195934943147014e-05,
#  1.4979395077304823e-05,
# ...
